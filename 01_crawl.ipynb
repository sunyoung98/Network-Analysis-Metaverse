# %%
from google_play_scraper import Sort, reviews, app
import pandas as pd
import time
from tqdm import tqdm, trange

# %%
roblox_dfs = []
token = None

# %%
for _ in trange(10000):
    review, token = reviews(
        'com.roblox.client',
        lang = 'en',
        country = 'us',
        sort = Sort.MOST_RELEVANT,
        count = 100,
        continuation_token = token
    )

    roblox_dfs.append(pd.DataFrame(review))
# Out:
# 100%|██████████| 10000/10000 [5:31:46<00:00,  1.99s/it]

# %%
len(roblox_dfs)
# Out:
# 10000

# %%
roblox_df = pd.concat(roblox_dfs).reset_index(drop = True)

# %%
roblox_df.to_csv('./roblox.csv')

# %%
zepeto_dfs = []
token = None

# %%
for _ in trange(10000):
    review, token = reviews(
        'me.zepeto.main',
        lang = 'en',
        country = 'us',
        sort = Sort.MOST_RELEVANT,
        count = 100,
        continuation_token = token
    )

    zepeto_dfs.append(pd.DataFrame(review))
# Out:
# 100%|██████████| 10000/10000 [36:41<00:00,  4.54it/s]

# %%
zepeto_df = pd.concat(zepeto_dfs).reset_index(drop = True)

# %%
zepeto_df.to_csv('./zepeto.csv')

# %%
roblox_df
# Out:
#                                 reviewId       userName  \
# 0   05426917-05d0-4cce-89d7-27fa81c313f3     LT. Silver
# 1   1ef0a865-6bb8-4d2b-911c-ac0603ec3091       Hiba Nur
# 2   6822f649-eeb4-420b-9630-920709c741c7  Graham Purdue
# 3   350fe8a7-7acd-4520-8382-1e8b3fa60b06     Amber Wood
# 4   1c0c638e-8c94-4421-bd3c-0b13d2f1aed5   Sophia Lewis
# ..                                   ...            ...
# 95  57acbd44-e9da-48ea-9517-1c4895e1e871  A Google user
# 96  bc503e81-75a2-42c6-8325-d1558687008d  A Google user
# 97  90259a82-d17a-4fd4-b86e-5e446de4cc1b  A Google user
# 98  07449187-2d62-43f1-a237-0683f8ca7b82  A Google user
# 99  7512f135-01fc-40c0-a9bc-25fd50b58f25  A Google user
#
#                                             userImage  \
# 0   https://play-lh.googleusercontent.com/a-/AD_cM...
# 1   https://play-lh.googleusercontent.com/a/AAcHTt...
# 2   https://play-lh.googleusercontent.com/a/AAcHTt...
# 3   https://play-lh.googleusercontent.com/a-/AD_cM...
# ...

# %%
zepeto_df
# Out:
#                                     reviewId            userName  \
# 0       06bd3c3f-da9e-4dc4-b8a6-a3527d42937b          Ren Gamble
# 1       e70e0618-e47a-4c45-8351-0decfa74e2d7          Lita Cross
# 2       84a39921-7a5f-4785-a0a4-4445d3bed767      Cricket Cowles
# 3       7c30c700-6b93-4d03-8c9c-9f8d1728ee73            grasszen
# 4       2e42b68f-a7c9-416e-9294-3556c03585ca           Nene Z qt
# ...                                      ...                 ...
# 115402  216320bc-49e0-45f4-9e1f-c006e9f8d17a  Joana angela Lopez
# 115403  7f402bb6-22dd-4306-9448-36bfc7835f53                EliD
# 115404  fa33d0ac-54a4-4886-9833-ecbee1bc1211               B Das
# 115405  78c46bb9-741e-41ec-8d1e-b1efe69d3059              vv hgg
# 115406  bfbc486c-256a-491a-8076-b79bc21f8d8f        Marilyn Long
#
#                                                 userImage  \
# 0       https://play-lh.googleusercontent.com/a-/AD_cM...
# 1       https://play-lh.googleusercontent.com/a-/AD_cM...
# ...

# %%
roblox_df = roblox_df.reset_index(drop = True)

# %%
roblox_df.loc[0:99999].to_csv('./roblox1.csv')
roblox_df.loc[100000:199999].to_csv('./roblox2.csv')
roblox_df.loc[200000:299999].to_csv('./roblox3.csv')
roblox_df.loc[300000:399999].to_csv('./roblox4.csv')
roblox_df.loc[400000:].to_csv('./roblox5.csv')
