# %%
from google_play_scraper import Sort, reviews, app
import pandas as pd
import time
from tqdm import tqdm, trange

# %%
roblox_dfs = []
token = None

# %%
for _ in trange(10000):
    review, token = reviews(
        'com.roblox.client',
        lang = 'en',
        country = 'us',
        sort = Sort.MOST_RELEVANT,
        count = 100,
        continuation_token = token
    )

    roblox_dfs.append(pd.DataFrame(review))
# Out:
#  37%|███▋      | 3698/10000 [4:03:19<6:54:39,  3.95s/it]
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File /usr/lib/python3.8/urllib/request.py:1354, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1353 try:
# -> 1354     h.request(req.get_method(), req.selector, req.data, headers,
#    1355               encode_chunked=req.has_header('Transfer-encoding'))
#    1356 except OSError as err: # timeout error
#
# File /usr/lib/python3.8/http/client.py:1256, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1255 """Send a complete request to the server."""
# -> 1256 self._send_request(method, url, body, headers, encode_chunked)
#
# File /usr/lib/python3.8/http/client.py:1302, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1301     body = _encode(body, 'body')
# -> 1302 self.endheaders(body, encode_chunked=encode_chunked)
#
# File /usr/lib/python3.8/http/client.py:1251, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1250     raise CannotSendHeader()
# -> 1251 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File /usr/lib/python3.8/http/client.py:1011, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1010 del self._buffer[:]
# -> 1011 self.send(msg)
#    1013 if message_body is not None:
#    1014
#    1015     # create a consistent interface to message_body
#
# File /usr/lib/python3.8/http/client.py:951, in HTTPConnection.send(self, data)
#     950 if self.auto_open:
# --> 951     self.connect()
#     952 else:
#
# File /usr/lib/python3.8/http/client.py:1418, in HTTPSConnection.connect(self)
#    1416 "Connect to a host on a given (SSL) port."
# -> 1418 super().connect()
#    1420 if self._tunnel_host:
#
# File /usr/lib/python3.8/http/client.py:922, in HTTPConnection.connect(self)
#     921 """Connect to the host and port specified in __init__."""
# --> 922 self.sock = self._create_connection(
#     923     (self.host,self.port), self.timeout, self.source_address)
#     924 self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# File /usr/lib/python3.8/socket.py:808, in create_connection(address, timeout, source_address)
#     807 try:
# --> 808     raise err
#     809 finally:
#     810     # Break explicitly a reference cycle
#
# File /usr/lib/python3.8/socket.py:796, in create_connection(address, timeout, source_address)
#     795     sock.bind(source_address)
# --> 796 sock.connect(sa)
#     797 # Break explicitly a reference cycle
#
# OSError: [Errno 99] Cannot assign requested address
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# Cell In[6], line 2
#       1 for _ in trange(10000):
# ----> 2     review, token = reviews(
#       3         'com.roblox.client',
#       4         lang = 'en',
#       5         country = 'us',
#       6         sort = Sort.MOST_RELEVANT,
#       7         count = 100,
#       8         continuation_token = token
#       9     )
#      11     roblox_dfs.append(pd.DataFrame(review))
#
# File ~/.local/lib/python3.8/site-packages/google_play_scraper/features/reviews.py:91, in reviews(app_id, lang, country, sort, count, filter_score_with, continuation_token)
#      88     _fetch_count = MAX_COUNT_EACH_FETCH
#      90 try:
# ---> 91     review_items, token = _fetch_review_items(
#      92         url, app_id, sort, _fetch_count, filter_score_with, token
#      93     )
#      94 except (TypeError, IndexError):
#      95     token = None
#
# File ~/.local/lib/python3.8/site-packages/google_play_scraper/features/reviews.py:34, in _fetch_review_items(url, app_id, sort, count, filter_score_with, pagination_token)
#      26 def _fetch_review_items(
#      27     url: str,
#      28     app_id: str,
#    (...)
#      32     pagination_token: Optional[str],
#      33 ):
# ---> 34     dom = post(
#      35         url,
#      36         Formats.Reviews.build_body(
#      37             app_id,
#      38             sort,
#      39             count,
#      40             "null" if filter_score_with is None else filter_score_with,
#      41             pagination_token,
#      42         ),
#      43         {"content-type": "application/x-www-form-urlencoded"},
#      44     )
#      46     match = json.loads(Regex.REVIEWS.findall(dom)[0])
#      48     return json.loads(match[0][2])[0], json.loads(match[0][2])[-1][-1]
#
# File ~/.local/lib/python3.8/site-packages/google_play_scraper/utils/request.py:23, in post(url, data, headers)
#      22 def post(url: str, data: Union[str, bytes], headers: dict) -> str:
# ---> 23     return _urlopen(Request(url, data=data, headers=headers))
#
# File ~/.local/lib/python3.8/site-packages/google_play_scraper/utils/request.py:10, in _urlopen(obj)
#       8 def _urlopen(obj):
#       9     try:
# ---> 10         resp = urlopen(obj)
#      11     except HTTPError as e:
#      12         if e.code == 404:
#
# File /usr/lib/python3.8/urllib/request.py:222, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220 else:
#     221     opener = _opener
# --> 222 return opener.open(url, data, timeout)
#
# File /usr/lib/python3.8/urllib/request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     522     req = meth(req)
#     524 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 525 response = self._open(req, data)
#     527 # post-process response
#     528 meth_name = protocol+"_response"
#
# File /usr/lib/python3.8/urllib/request.py:542, in OpenerDirector._open(self, req, data)
#     539     return result
#     541 protocol = req.type
# --> 542 result = self._call_chain(self.handle_open, protocol, protocol +
#     543                           '_open', req)
#     544 if result:
#     545     return result
#
# File /usr/lib/python3.8/urllib/request.py:502, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     500 for handler in handlers:
#     501     func = getattr(handler, meth_name)
# --> 502     result = func(*args)
#     503     if result is not None:
#     504         return result
#
# File /usr/lib/python3.8/urllib/request.py:1397, in HTTPSHandler.https_open(self, req)
#    1396 def https_open(self, req):
# -> 1397     return self.do_open(http.client.HTTPSConnection, req,
#    1398         context=self._context, check_hostname=self._check_hostname)
#
# File /usr/lib/python3.8/urllib/request.py:1357, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1354         h.request(req.get_method(), req.selector, req.data, headers,
#    1355                   encode_chunked=req.has_header('Transfer-encoding'))
#    1356     except OSError as err: # timeout error
# -> 1357         raise URLError(err)
#    1358     r = h.getresponse()
#    1359 except:
#
# URLError: <urlopen error [Errno 99] Cannot assign requested address>

# %%
len(roblox_dfs)
# Out:
# 3698

# %%
roblox_df = pd.concat(roblox_dfs)

# %%
roblox_df.to_csv('./roblox.csv')

# %%
zepeto_dfs = []
token = None

# %%
for _ in trange(10000):
    review, token = reviews(
        'me.zepeto.main',
        lang = 'en',
        country = 'us',
        sort = Sort.MOST_RELEVANT,
        count = 100,
        continuation_token = token
    )

    zepeto_dfs.append(pd.DataFrame(review))
# Out:
# 100%|██████████| 10000/10000 [34:29<00:00,  4.83it/s]

# %%
zepeto_df = pd.concat(zepeto_dfs).reset_index(drop = True)

# %%
zepeto_df.to_csv('./zepeto.csv')

# %%
roblox_df = pd.read_csv('./roblox.csv', index_col = 0)
# Out:
# /tmp/ipykernel_2408368/862007995.py:1: DtypeWarning: Columns (9,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   roblox_df = pd.read_csv('./roblox.csv', index_col = 0)

# %%
zepeto_df
# Out:
#                                     reviewId            userName  \
# 0       06bd3c3f-da9e-4dc4-b8a6-a3527d42937b          Ren Gamble
# 1       e70e0618-e47a-4c45-8351-0decfa74e2d7          Lita Cross
# 2       84a39921-7a5f-4785-a0a4-4445d3bed767      Cricket Cowles
# 3       7c30c700-6b93-4d03-8c9c-9f8d1728ee73            grasszen
# 4       2e42b68f-a7c9-416e-9294-3556c03585ca           Nene Z qt
# ...                                      ...                 ...
# 115323  90de0a84-0de0-430e-88c3-73f38afb4142       A Google user
# 115324  216320bc-49e0-45f4-9e1f-c006e9f8d17a  Joana angela Lopez
# 115325  7f402bb6-22dd-4306-9448-36bfc7835f53                EliD
# 115326  fa33d0ac-54a4-4886-9833-ecbee1bc1211               B Das
# 115327  78c46bb9-741e-41ec-8d1e-b1efe69d3059              vv hgg
#
#                                                 userImage  \
# 0       https://play-lh.googleusercontent.com/a-/AD_cM...
# 1       https://play-lh.googleusercontent.com/a-/AD_cM...
# 2       https://play-lh.googleusercontent.com/a/AAcHTt...
# 3       https://play-lh.googleusercontent.com/a-/AD_cM...
# 4       https://play-lh.googleusercontent.com/a/AAcHTt...
# ...                                                   ...
# 115323  https://play-lh.googleusercontent.com/EGemoI2N...
# 115324  https://play-lh.googleusercontent.com/a/AAcHTt...
# 115325  https://play-lh.googleusercontent.com/a-/AD_cM...
# 115326  https://play-lh.googleusercontent.com/a-/AD_cM...
# 115327  https://play-lh.googleusercontent.com/a/AAcHTt...
#
#                                                   content  score  \
# 0       I've been playing Zepeto since there was only ...      5
# 1       I love this app!!! But there are clothing item...      5
# 2       Great app! It is a little confusi g to get aro...      5
# 3       Been playing this for more than years, im obse...      4
# 4       Zepeto is a awesome app! It's fun to use and s...      4
# ...                                                   ...    ...
# 115323                                            гоё гоё      1
# 115324                        Yumica Yumica Yumica Yumica      5
# 115325                 ZEPETO ZEPETO ZEPETO ZEPETO ZEPETO      5
# 115326                           Hehe Hehe Hehe Hehe Hehe      5
# 115327  កកកកកកកកកកកកកកកកកកកកកកកកកកកកកកកកកកកកកកកកកកកកកក...      5
#
#         thumbsUpCount reviewCreatedVersion                  at  \
# 0                2208             3.28.000 2023-05-19 15:38:23
# 1                2266             3.27.100 2023-05-11 20:03:05
# 2                1585             3.26.500 2023-04-24 22:24:57
# 3                  86             3.29.100 2023-06-27 08:38:33
# 4                4242             3.20.000 2023-02-02 01:23:20
# ...               ...                  ...                 ...
# 115323              0                 None 2019-07-05 04:42:29
# 115324              0                 None 2021-10-12 16:47:32
# 115325              0                 None 2021-09-08 20:04:37
# 115326              0                 None 2021-06-14 06:45:39
# 115327              0                 None 2021-11-26 13:22:01
#
#                                              replyContent  \
# 0                                                    None
# 1                                                    None
# 2                                                    None
# 3                                                    None
# 4                                                    None
# ...                                                   ...
# 115323                                               None
# 115324                                               None
# 115325  Have a lovely time! EliD, Thanks for playing Z...
# 115326                                               None
# 115327                                               None
#
#                   repliedAt appVersion
# 0                       NaT   3.28.000
# 1                       NaT   3.27.100
# 2                       NaT   3.26.500
# 3                       NaT   3.29.100
# 4                       NaT   3.20.000
# ...                     ...        ...
# 115323                  NaT       None
# 115324                  NaT       None
# 115325  2021-09-09 01:28:51       None
# 115326                  NaT       None
# 115327                  NaT       None
#
# [115328 rows x 11 columns]

# %%
roblox_df
# Out:
#                                 reviewId          userName  \
# 0   05426917-05d0-4cce-89d7-27fa81c313f3        LT. Silver
# 1   1ef0a865-6bb8-4d2b-911c-ac0603ec3091          Hiba Nur
# 2   1c0c638e-8c94-4421-bd3c-0b13d2f1aed5      Sophia Lewis
# 3   b8da4c78-1fd1-4d83-922e-814fb1fc0d72          mamaLo Z
# 4   daad7979-0220-4202-a979-3383119e2fff  KitKat Scratcher
# ..                                   ...               ...
# 95  d249f15d-47ec-459c-87bc-d4601b06b3ca     A Google user
# 96  5181a2bd-8f14-48f2-b58e-1e7b06e67353      Aidan Hauser
# 97  551dece1-de23-4a17-b548-1088d6264c7c     A Google user
# 98  3b87cace-a1ec-4c40-b041-f19818c636d5     A Google user
# 99  39af83dc-3b5a-4d1b-bc06-8ae7ee371b70    Yadira Vergara
#
#                                             userImage  \
# 0   https://play-lh.googleusercontent.com/a-/AD_cM...
# 1   https://play-lh.googleusercontent.com/a/AAcHTt...
# 2   https://play-lh.googleusercontent.com/a/AAcHTt...
# 3   https://play-lh.googleusercontent.com/a-/AD_cM...
# 4   https://play-lh.googleusercontent.com/a/AAcHTt...
# ..                                                ...
# 95  https://play-lh.googleusercontent.com/EGemoI2N...
# 96  https://play-lh.googleusercontent.com/a/AAcHTt...
# 97  https://play-lh.googleusercontent.com/EGemoI2N...
# 98  https://play-lh.googleusercontent.com/EGemoI2N...
# 99  https://play-lh.googleusercontent.com/a/AAcHTt...
#
#                                               content  score  thumbsUpCount  \
# 0   As a person who has played this game for many ...      4            219
# 1   Overall the game is pretty good, but there are...      4           4129
# 2   Hello, I like on how it is very limitless and ...      3            283
# 3   Gotta say, great app! Been playing for years n...      4            108
# 4   I've been playing for years, and this game is ...      4            883
# ..                                                ...    ...            ...
# 95  I play this game every day, I am going to miss...      5              0
# 96  its a really good game but sometimes theres al...      5              0
# 97  i think this game is good but it takes to long...      2              0
# 98                   It a good way to help kids learn      5              0
# 99  It's amazing I love it you cane make friends a...      5              0
#
#    reviewCreatedVersion                   at replyContent repliedAt  \
# 0             2.581.563  2023-07-02 19:51:21          NaN       NaN
# 1             2.581.563  2023-06-27 02:54:39          NaN       NaN
# 2             2.581.563  2023-06-28 03:30:25          NaN       NaN
# 3             2.581.563  2023-07-04 12:32:28          NaN       NaN
# 4             2.578.564  2023-06-28 15:10:06          NaN       NaN
# ..                  ...                  ...          ...       ...
# 95         2.413.370526  2019-12-30 21:52:33          NaN       NaN
# 96         2.455.413788  2020-11-28 17:35:33          NaN       NaN
# 97                  NaN  2019-03-09 11:35:28          NaN       NaN
# 98         2.355.243337  2018-09-30 04:09:46          NaN       NaN
# 99         2.469.419180  2021-03-23 03:50:03          NaN       NaN
#
#       appVersion
# 0      2.581.563
# 1      2.581.563
# 2      2.581.563
# 3      2.581.563
# 4      2.578.564
# ..           ...
# 95  2.413.370526
# 96  2.455.413788
# 97           NaN
# 98  2.355.243337
# 99  2.469.419180
#
# [369800 rows x 11 columns]
